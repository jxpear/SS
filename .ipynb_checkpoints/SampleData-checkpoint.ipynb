# %%
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
clean_df = pd.read_csv('Aug2021_CleanData.csv')
raw_df= pd.read_csv('Aug2021_RawData.csv')
clean_df.head()
clean_df.drop(clean_df.columns[0], axis= 1, inplace= True)
clean_df.head(10)
clean_df1.head(10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0                                    Id  DeviceGeneratedShowerId  \
# 0           0  08d95629-b372-4041-8b47-8d346f0f15c1               1389086653
# 1           1  08d95629-b372-4041-8b47-8d346f0f15c1               1389086653
# 2           2  08d95629-b372-401d-8875-e027284cc4d6               1389086653
# 3           3  08d95629-b372-401d-8875-e027284cc4d6               1389086653
# 4           4  08d95629-b371-4ffa-866c-35363b017a34               1389086653
# 5           5  08d95629-b371-4ffa-866c-35363b017a34               1389086653
# 6           6  08d95629-b371-4fd5-8629-c67b7b93eca2               1389086653
# 7           7  08d95629-b371-4fd5-8629-c67b7b93eca2               1389086653
# 8           8  08d95629-b371-4fb1-8e72-191b260f8e33               1389086653
# 9           9  08d95629-b371-4fb1-8e72-191b260f8e33               1389086653
#
#               SampleDateTime  IsValveOpen  IsUserDetected  WaterTemperature_F  \
# 0  2021-08-01 21:04:47-05:00            1               0           72.680000
# 1  2021-08-01 21:04:47-05:00            1               0           72.680000
# 2  2021-08-01 21:04:49-05:00            1               0           78.309998
# 3  2021-08-01 21:04:49-05:00            1               0           78.309998
# 4  2021-08-01 21:04:52-05:00            1               1           82.739998
# 5  2021-08-01 21:04:52-05:00            1               1           82.739998
# 6  2021-08-01 21:04:54-05:00            1               0           85.730003
# 7  2021-08-01 21:04:54-05:00            1               0           85.730003
# 8  2021-08-01 21:04:56-05:00            1               0           87.849998
# 9  2021-08-01 21:04:56-05:00            1               0           87.849998
#
#    WaterPressure_hPa  AvailableMemory_Kb  BatteryVoltage_V  ... SonarActive  \
# 0               2047           39.655998               4.8  ...           0
# 1               2047           39.655998               4.8  ...           0
# 2               2047           39.530998               4.7  ...           0
# 3               2047           39.530998               4.7  ...           0
# 4               2047           39.484001               4.7  ...           0
# 5               2047           39.484001               4.7  ...           0
# 6               2047           39.438000               4.7  ...           0
# 7               2047           39.438000               4.7  ...           0
# 8               2047           39.390999               4.7  ...           0
# 9               2047           39.390999               4.7  ...           0
#
#            ParticleDeviceId DeviceMacAddress DeviceName  \
# 0  390025000447393032323330              NaN     Room 1
# 1  390025000447393032323330              NaN     Room 1
# 2  390025000447393032323330              NaN     Room 1
# 3  390025000447393032323330              NaN     Room 1
# 4  390025000447393032323330              NaN     Room 1
# 5  390025000447393032323330              NaN     Room 1
# 6  390025000447393032323330              NaN     Room 1
# 7  390025000447393032323330              NaN     Room 1
# 8  390025000447393032323330              NaN     Room 1
# 9  390025000447393032323330              NaN     Room 1
#
#                                  RoomId  RoomNumber  \
# 0  08d982d9-71cb-4f00-862e-18c53bc5c568         S13
# 1  08d99d65-a109-49ca-8454-655ab7a4541d       D8-21
# 2  08d982d9-71cb-4f00-862e-18c53bc5c568         S13
# 3  08d99d65-a109-49ca-8454-655ab7a4541d       D8-21
# 4  08d982d9-71cb-4f00-862e-18c53bc5c568         S13
# 5  08d99d65-a109-49ca-8454-655ab7a4541d       D8-21
# 6  08d982d9-71cb-4f00-862e-18c53bc5c568         S13
# 7  08d99d65-a109-49ca-8454-655ab7a4541d       D8-21
# 8  08d982d9-71cb-4f00-862e-18c53bc5c568         S13
# 9  08d99d65-a109-49ca-8454-655ab7a4541d       D8-21
#
#                              LocationId   LocationName  \
# 0  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 1  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 2  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 3  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 4  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 5  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 6  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 7  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 8  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
# 9  08d982d9-49b4-4cd1-8ba0-1da89992688d  Demo Location
#
#                             FranchiseId   FranchiseName
# 0  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 1  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 2  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 3  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 4  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 5  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 6  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 7  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 8  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
# 9  08d982d9-2e37-4f48-8e97-24dede6696f5  Demo Franchise
#
# [10 rows x 27 columns]

# %%
clean_df.sort_values(by)
# Out:
#                                 DeviceGeneratedShowerId  IsValveOpen  \
# DeviceGeneratedShowerId                        1.000000          NaN
# IsValveOpen                                         NaN          NaN
# IsUserDetected                                 0.008026          NaN
# WaterTemperature_F                             0.114850          NaN
# WaterPressure_hPa                             -0.206955          NaN
# AvailableMemory_Kb                            -0.112600          NaN
# BatteryVoltage_V                               0.007487          NaN
# GDSEventId                                     0.027095          NaN
# FirmwareGeneratedShowerEventId                      NaN          NaN
# ParticleDeviceId                                    NaN          NaN
# showerLength_sec                              -0.124891          NaN
# ValveClosedTime_sec                           -0.167268          NaN
# ValveOpenTime_sec                             -0.087518          NaN
# ValveActuations                               -0.032998          NaN
#
#                                 IsUserDetected  WaterTemperature_F  \
# DeviceGeneratedShowerId               0.008026            0.114850
# IsValveOpen                                NaN                 NaN
# IsUserDetected                        1.000000            0.446822
# WaterTemperature_F                    0.446822            1.000000
# WaterPressure_hPa                    -0.357519           -0.511173
# AvailableMemory_Kb                   -0.480239           -0.476639
# BatteryVoltage_V                      0.011603           -0.072262
# GDSEventId                            0.016760            0.029520
# FirmwareGeneratedShowerEventId             NaN                 NaN
# ParticleDeviceId                           NaN                 NaN
# showerLength_sec                     -0.257501           -0.046739
# ValveClosedTime_sec                  -0.172667            0.042644
# ValveOpenTime_sec                    -0.243516           -0.071298
# ValveActuations                      -0.232396            0.020588
#
#                                 WaterPressure_hPa  AvailableMemory_Kb  \
# DeviceGeneratedShowerId                 -0.206955           -0.112600
# IsValveOpen                                   NaN                 NaN
# IsUserDetected                          -0.357519           -0.480239
# WaterTemperature_F                      -0.511173           -0.476639
# WaterPressure_hPa                        1.000000            0.419372
# AvailableMemory_Kb                       0.419372            1.000000
# BatteryVoltage_V                        -0.208915           -0.052876
# GDSEventId                              -0.142236            0.109318
# FirmwareGeneratedShowerEventId                NaN                 NaN
# ParticleDeviceId                              NaN                 NaN
# showerLength_sec                         0.225327            0.197714
# ValveClosedTime_sec                      0.085824            0.115283
# ValveOpenTime_sec                        0.236995            0.193310
# ValveActuations                          0.107926            0.144972
#
#                                 BatteryVoltage_V  GDSEventId  \
# DeviceGeneratedShowerId                 0.007487    0.027095
# IsValveOpen                                  NaN         NaN
# IsUserDetected                          0.011603    0.016760
# WaterTemperature_F                     -0.072262    0.029520
# WaterPressure_hPa                      -0.208915   -0.142236
# AvailableMemory_Kb                     -0.052876    0.109318
# BatteryVoltage_V                        1.000000   -0.045683
# GDSEventId                             -0.045683    1.000000
# FirmwareGeneratedShowerEventId               NaN         NaN
# ParticleDeviceId                             NaN         NaN
# showerLength_sec                       -0.144177   -0.109668
# ValveClosedTime_sec                    -0.178289   -0.129690
# ValveOpenTime_sec                      -0.106456   -0.083146
# ValveActuations                        -0.153810    0.144990
#
#                                 FirmwareGeneratedShowerEventId  \
# DeviceGeneratedShowerId                                    NaN
# IsValveOpen                                                NaN
# IsUserDetected                                             NaN
# WaterTemperature_F                                         NaN
# WaterPressure_hPa                                          NaN
# AvailableMemory_Kb                                         NaN
# BatteryVoltage_V                                           NaN
# GDSEventId                                                 NaN
# FirmwareGeneratedShowerEventId                             NaN
# ParticleDeviceId                                           NaN
# showerLength_sec                                           NaN
# ValveClosedTime_sec                                        NaN
# ValveOpenTime_sec                                          NaN
# ValveActuations                                            NaN
#
#                                 ParticleDeviceId  showerLength_sec  \
# DeviceGeneratedShowerId                      NaN         -0.124891
# IsValveOpen                                  NaN               NaN
# IsUserDetected                               NaN         -0.257501
# WaterTemperature_F                           NaN         -0.046739
# WaterPressure_hPa                            NaN          0.225327
# AvailableMemory_Kb                           NaN          0.197714
# BatteryVoltage_V                             NaN         -0.144177
# GDSEventId                                   NaN         -0.109668
# FirmwareGeneratedShowerEventId               NaN               NaN
# ParticleDeviceId                             NaN               NaN
# showerLength_sec                             NaN          1.000000
# ValveClosedTime_sec                          NaN          0.634057
# ValveOpenTime_sec                            NaN          0.959055
# ValveActuations                              NaN          0.666410
#
#                                 ValveClosedTime_sec  ValveOpenTime_sec  \
# DeviceGeneratedShowerId                   -0.167268          -0.087518
# IsValveOpen                                     NaN                NaN
# IsUserDetected                            -0.172667          -0.243516
# WaterTemperature_F                         0.042644          -0.071298
# WaterPressure_hPa                          0.085824           0.236995
# AvailableMemory_Kb                         0.115283           0.193310
# BatteryVoltage_V                          -0.178289          -0.106456
# GDSEventId                                -0.129690          -0.083146
# FirmwareGeneratedShowerEventId                  NaN                NaN
# ParticleDeviceId                                NaN                NaN
# showerLength_sec                           0.634057           0.959055
# ValveClosedTime_sec                        1.000000           0.389085
# ValveOpenTime_sec                          0.389085           1.000000
# ValveActuations                            0.433905           0.634962
#
#                                 ValveActuations
# DeviceGeneratedShowerId               -0.032998
# IsValveOpen                                 NaN
# IsUserDetected                        -0.232396
# WaterTemperature_F                     0.020588
# WaterPressure_hPa                      0.107926
# AvailableMemory_Kb                     0.144972
# BatteryVoltage_V                      -0.153810
# GDSEventId                             0.144990
# FirmwareGeneratedShowerEventId              NaN
# ParticleDeviceId                            NaN
# showerLength_sec                       0.666410
# ValveClosedTime_sec                    0.433905
# ValveOpenTime_sec                      0.634962
# ValveActuations                        1.000000

# %% [markdown]
# what basic study can we do to find which variables can affect the outcome
# what kind of changes to a certain variable
# focus on cleaning or focus on questions to create equations
# github copilot and vs code version of visual studio
# haskell
